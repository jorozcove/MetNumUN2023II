# %% [markdown]
# <a href="https://colab.research.google.com/github/jorozcove/MetNumUN2023II/blob/main/lab_4/jorozcove_Lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SymPyLab
#
# SymPy’s documentation
# - https://docs.sympy.org/latest/index.html

# %% [markdown]
# ## SymPy’s polynomials
# - https://docs.sympy.org/latest/modules/polys/basics.html#polynomials
#
# $$ P_n(x) =  a_n x^n + a_{n-1} x^{n-1} + a_{n-2} x^{n-2} +\cdots +  a_1 x  + a_0$$
#
# $$P_n(x) = 0 $$
#
# $$a_n x^n + a_{n-1} x^{n-1} + a_{n-2} x^{n-2} +\cdots +  a_1 x  + a_0 = 0$$
#
# $$(x-r_1) Q_{n-1}(x) = P_n(x)$$
# $$(x-r_1) (x - r_2) Q_{n-2}(x) = P_n(x)$$
# $$ \vdots $$
#
# - (x-10)(x-4)(x-5)(x+20)(x-7)(x+1)(x-1)(x+12)(x-3)(x+15) = 15120000 - 12492000 x - 11909400 x^2 + 12361310 x^3 - 3261777 x^4 + 134582 x^5 + 51499 x^6 - 3910 x^7 - 323 x^8 + 18 x^9 + x^10
#
# - (15120000 - 12492000 x - 11909400 x^2 + 12361310 x^3 - 3261777 x^4 + 134582 x^5 + 51499 x^6 - 3910 x^7 - 323 x^8 + 18 x^9 + x^10) / (x-5) = x^9 + 23 x^8 - 208 x^7 - 4950 x^6 + 26749 x^5 + 268327 x^4 - 1920142 x^3 + 2760600 x^2 + 1893600 x - 3024000

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol
from sympy import div

x = Symbol('x')

p = 15120000 - 12492000*x - 11909400*x**2 + 12361310*x**3 - 3261777*x**4 + 134582*x**5 + 51499*x**6 - 3910*x**7 - 323*x**8 + 18*x**9 + x**10

p, r = div(p,  x-1)

print(p)
print(r)

p, r = div(p,  x-2)

print(p)
print(r)

p, r = div(p,  x-3)

print(p)
print(r)

p, r = div(p,  x-5)

print(p)
print(r)
# Out:
# x**9 + 19*x**8 - 304*x**7 - 4214*x**6 + 47285*x**5 + 181867*x**4 - 3079910*x**3 + 9281400*x**2 - 2628000*x - 15120000
# 0
# x**8 + 21*x**7 - 262*x**6 - 4738*x**5 + 37809*x**4 + 257485*x**3 - 2564940*x**2 + 4151520*x + 5675040
# -3769920
# x**7 + 24*x**6 - 190*x**5 - 5308*x**4 + 21885*x**3 + 323140*x**2 - 1595520*x - 635040
# 3769920
# x**6 + 29*x**5 - 45*x**4 - 5533*x**3 - 5780*x**2 + 294240*x - 124320
# -1256640

# %%
p = 15120000 - 12492000*x - 11909400*x**2 + 12361310*x**3 - 3261777*x**4 + 134582*x**5 + 51499*x**6 - 3910*x**7 - 323*x**8 + 18*x**9 + x**10

p, r = div(p,  x-5)

print(p)
print(r)
# Out:
# x**9 + 23*x**8 - 208*x**7 - 4950*x**6 + 26749*x**5 + 268327*x**4 - 1920142*x**3 + 2760600*x**2 + 1893600*x - 3024000
# 0

# %% [markdown]
# ## SymPy’s polynomial simple univariate polynomial factorization
# - https://docs.sympy.org/latest/modules/polys/wester.html#simple-univariate-polynomial-factorization
# - factor(p = 15120000 - 12492000*x - 11909400*x\*\*2 + 12361310*x\*\*3 - 3261777*x\*\*4 + 134582*x\*\*5 + 51499*x\*\*6 - 3910*x\*\*7 - 323*x**8 + 18*x\*\*9 + x\*\*10)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(15120000 - 12492000*x - 11909400*x**2 + 12361310*x**3 - 3261777*x**4 + 134582*x**5 + 51499*x**6 - 3910*x**7 - 323*x**8 + 18*x**9 + x**10)
# Out:
# (x - 10)*(x - 7)*(x - 5)*(x - 4)*(x - 3)*(x - 1)*(x + 1)*(x + 12)*(x + 15)*(x + 20)

# %% [markdown]
# ## SymPy’s solvers
# - https://docs.sympy.org/latest/tutorial/solvers.html
# -15120000 - 12492000*x - 11909400*x\*\*2 + 12361310*x\*\*3 - 3261777*x\*\*4 + 134582*x\*\*5 + 51499*x\*\*6 - 3910*x\*\*7 - 323*x**8 + 18*x\*\*9 + x\*\*10

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq
x = Symbol('x')
solveset(Eq(15120000 - 12492000*x - 11909400*x**2 + 12361310*x**3 - 3261777*x**4 + 134582*x**5 + 51499*x**6 - 3910*x**7 - 323*x**8 + 18*x**9 + x**10, 0), x)
# Out:
# {-20, -15, -12, -1, 1, 3, 4, 5, 7, 10}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq, sqrt, pi, E
x = Symbol('x')
solveset(Eq( x**2+sqrt(x) , 0), x)
# Out:
# {0, -1/2 - sqrt(3)*I/2, -1/2 + sqrt(3)*I/2}

# %% [markdown]
# *   Reference docs for the Poly Domains https://docs.sympy.org/dev/modules/polys/domainsref.html
#
# *   Introducing the Domains of the poly module https://docs.sympy.org/dev/modules/polys/domainsintro.html
#
# *   Internals of the Polynomial Manipulation Module https://docs.sympy.org/latest/modules/polys/internals.html

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**5 - 7*x**4  - 2*x**3 + 3*x**2 - 3*x - 12,domain='GF(3)')
# Out:
# x**3*(x + 1)**2

# %% [markdown]
# ## SymPy’s Symbolic and Numercical Complex Evaluations
# - https://docs.sympy.org/latest/modules/evalf.html](https://)
# - x = x2 + I*x1,y = y1 + 2I*y2, z = z2 + I*z2, x * y + z

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import symbols, I, N, pi, expand
x1, x2, y1, y2, z1, z2 = symbols("x1 x2 y1 y2 z1 z2", real=True)

x = x2 + I*x1
y = y1 + 2*I*y2
z = z2 + I*z2

print(x * y + z)
print(expand(x * y + z))
w=1/(pi + I)
print('w=',w)
w=N(w)
print('w=',w)
# Out:
# z2 + I*z2 + (y1 + 2*I*y2)*(I*x1 + x2)
# I*x1*y1 - 2*x1*y2 + x2*y1 + 2*I*x2*y2 + z2 + I*z2
# w= 1/(pi + I)
# w= 0.289025482222236 - 0.0919996683503752*I

# %% [markdown]
# ## Wolfram alpha answers question in natural languaje
#
# > Bloc con sangría
#
#
# - What is the average temperature in Girardot in January?
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Try the same question asked in Wolfram Alpha in ChatGPT**
#
# https://chat.openai.com/auth/login
#
# and post the answer screenshoot.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## SymPy’s integrate
#
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, sin, cos
x = Symbol('x')
integrate(sin(x)*cos(x)**2, x)
# Out:
# -cos(x)**3/3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, sin
x = Symbol('x')
integrate(sin(x)*cos(x)**2, (x,3,7))
# Out:
# cos(3)**3/3 - cos(7)**3/3

# %%
from sympy import Symbol, integrate, sin, N
x = Symbol('x')
N(integrate(sin(x)*cos(x)**2, (x,3,7)))
# Out:
# -0.466257104540972
